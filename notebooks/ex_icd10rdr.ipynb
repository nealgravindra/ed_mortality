# %%
import os
import sys

sfp = '/home/ngr/ushare/covid_ed/scripts/' # specify script filepath
sys.path.append(sfp)

import icd10reader

# %%
# pointers 
dfp = '/home/ngr/ushare/covid_ed/data/' # point to pickled df
fname = 'sample_pmh.pkl'

# %%
# CCI df
df = icd10reader.pkl2df(os.path.join(dfp,fname))
cci = icd10reader.icd102cci(df, verbose=True)
cci.head()
# Out:
# Starting construction of cci df...
# ... processed 41790-records in 81.39-s
#    PAT_ENC_CSN_ID  chronicDiseases_of_the_circulatory_system  \
# 0               0                                        1.0
# 1               1                                        NaN
# 2               2                                        NaN
# 3               3                                        NaN
# 4               4                                        1.0
#
#    chronicEndocrine,_nutritional,_and_metabolic_diseases_and_immunity_disorders  \
# 0                                                NaN
# 1                                                1.0
# 2                                                NaN
# 3                                                NaN
# 4                                                1.0
#
#    Diseases_of_the_genitourinary_system  Diseases_of_the_digestive_system  \
# 0                                   NaN                               NaN
# ...

# %%
# Elixhauser df
eh = icd10reader.icd102eh(df, verbose=True)
eh.head()
# Out:
# Starting construction of Elixhauser df...
# ... processed 41790-records in 64.85-s
#    PAT_ENC_CSN_ID  rdmsn_scr  mrtlt_scr  cc_hypothy  cc_dm  cc_chrnlung  \
# 0               0        0.0        0.0         NaN    NaN          NaN
# 1               1        0.0        0.0         1.0    NaN          NaN
# 2               2        0.0        0.0         NaN    NaN          NaN
# 3               3        0.0        0.0         NaN    NaN          NaN
# 4               4       14.0        3.0         NaN    1.0          1.0
#
#    cc_tumor  cc_htn  cc_depress  cc_perivasc  ...  cc_psych  cc_alcohol  \
# 0       NaN     NaN         NaN          NaN  ...       NaN         NaN
# 1       NaN     NaN         NaN          NaN  ...       NaN         NaN
# 2       NaN     NaN         NaN          NaN  ...       NaN         NaN
# 3       NaN     NaN         NaN          NaN  ...       NaN         NaN
# 4       NaN     NaN         NaN          NaN  ...       NaN         NaN
#
# ...
